# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.title("My first graph")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
